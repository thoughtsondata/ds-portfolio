# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import seaborn as sns
from cycler import cycler
from IPython.display import display
import datetime

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, KFold
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import roc_auc_score, roc_curve
import xgboost as xgb

# %%
df_test = pd.read_csv('./data/test.csv')
df_train = pd.read_csv('./data/train.csv')

# %%
print()
print('Train')
display(train.head(3))

print()
print('Test')
display(test.head(3))

print('Data Frame Shapes:', train.shape, test.shape)
print()

print('Data Describe')
display(train.describe())
# Out:
# Train
#    id      f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0   0 -1.373246  0.238887 -0.243376  0.567405 -0.647715  0.839326  0.113133
# 1   1  1.697021 -1.710322 -2.230332 -0.545661  1.113173 -1.552175  0.447825
# 2   2  1.681726  0.616746 -1.027689  0.810492 -0.609086  0.113965 -0.708660
#
#    f_07  f_08  f_09  f_10  f_11  f_12  f_13  f_14  f_15  f_16  f_17  f_18  \
# 0     1     5     1     3     3     3     1     6     1     0     7     4
# 1     1     3     4     0     2     3     0     1     0     4     6     0
# 2     1     0     2     6     6     4     3     1     2     2     1     4
#
#        f_19      f_20      f_21      f_22      f_23      f_24      f_25  \
# 0  0.298218 -0.919717  3.058541 -2.540739  0.766952 -2.730628 -0.208177
# 1 -3.147667 -1.075434  2.179050  2.278315 -0.633658 -1.217077 -3.782194
# 2  2.820733 -3.485342 -0.784235 -1.385775 -0.520558 -0.009121  2.788536
#
#        f_26        f_27        f_28  f_29  f_30  target
# ...

# %%
(train.target.value_counts() / len(train)).round(2)
# Out:
# 0    0.51
# 1    0.49
# Name: target, dtype: float64

# %% [markdown]
# ## Feature Engineering

# %%
# Read in the data
train = pd.read_csv('./data/train.csv', index_col=0)

test = pd.read_csv('./data/train.csv', index_col=0)

# %%
# Non numeric

# encoder = OrdinalEncoder()
# def tweak_f27(df):
#     dff=df.copy
#     df['char_unique']=df['f_27'].apply(lambda x: len(set(x)))
#     for i in range(df.f_27.str.len().max()):
#         df['f_27_char{}'.format(i+1)]=encoder.fit_transform(df['f_27'].str.get(i).values.reshape(-1,1))
#     return df.drop(['f_27'], axis=1)
    
# train = tweak_f27(train)
# test = tweak_f27(test)

# %%
# Top 3 feature interaction
# https://www.kaggle.com/code/ambrosm/tpsmay22-eda-which-makes-sense
# https://www.kaggle.com/code/wti200/analysing-interactions-with-shap 

for df in [train, test]:
    # Split string feature into 10 character features
    for i in range(10):
        df[f'ch{i}'] = df.f_27.str.get(i).apply(ord) - ord('A')
        
    # Unique character count
    df["unique_characters"] = df.f_27.apply(lambda s: len(set(s)))
    
    # Top 3 feature interactions
    df['i_02_21'] = (df.f_21 + df.f_02 > 5.2).astype(int) - (df.f_21 + df.f_02 < -5.3).astype(int)
    df['i_05_22'] = (df.f_22 + df.f_05 > 5.1).astype(int) - (df.f_22 + df.f_05 < -5.4).astype(int)
    i_00_01_26 = df.f_00 + df.f_01 + df.f_26
    df['i_00_01_26'] = (i_00_01_26 > 5.0).astype(int) - (i_00_01_26 < -5.0).astype(int)

# %% [markdown]
# ## Data preprocessing
#
# 1. Split training data into X and y
# 2. Split into training / validation set
# 3. Convert non-numeric feature into a numerical representation
# 4. Scale each feature between 0-1

# %%
scaler = StandardScaler()

# 1. Split training data into X and y

y = train.target.values
X = train.drop(['target'], axis=1).values

X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X_test = pd.DataFrame(scaler.transform(test))


# 2. Split training data into training and validation
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-ae569db6bfea> in <module>
#       6 X = train.drop(['target'], axis=1).values
#       7
# ----> 8 X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
#       9 X_test = pd.DataFrame(scaler.transform(test))
#      10
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# ...

# %%
xgb_model = xgb.XGBClassifier()
xgb_model.fit(X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-45c615031b96> in <module>
# ----> 1 X.dtypes
#
# AttributeError: 'numpy.ndarray' object has no attribute 'dtypes'
